# %%
import numpy as np
import yfinance as yf
import pandas as pd
# import talib as ta
import tulipy as ti
from sklearn.metrics import (accuracy_score,confusion_matrix,
                            ConfusionMatrixDisplay,f1_score, classification_report)
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from qiskit.circuit.library import ZZFeatureMap
import matplotlib.pyplot as plt
from qiskit import *
from qiskit_aer import AerSimulator
from qiskit.circuit import QuantumCircuit
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import Session, Sampler as Sampler, QiskitRuntimeService, Options
from qiskit.visualization import plot_histogram
from math import asin, sqrt

# %%
ticker= "AAPL"
data = yf.download(ticker, start="2018-01-01", end="2021-01-01")
print(data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-01-02  42.540001  43.075001  42.314999  43.064999  40.615898  102223600
# 2018-01-03  43.132500  43.637501  42.990002  43.057499  40.608810  118071600
# 2018-01-04  43.134998  43.367500  43.020000  43.257500  40.797451   89738400
# 2018-01-05  43.360001  43.842499  43.262501  43.750000  41.261932   94640000
# 2018-01-08  43.587502  43.902500  43.482498  43.587502  41.108677   82271200

# %%
data['Adj Close'].plot()
# Out:
# <Axes: xlabel='Date'>
